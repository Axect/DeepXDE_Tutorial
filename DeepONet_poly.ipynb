# %%
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt

import rft1d
# Out:
# Using backend: pytorch

# %% [markdown]
# ## Data Generation

# %%
y = rft1d.randn1d(150, 100, 50)

# %%
plt.plot(y[:5].T)
plt.show()

# %%
x = np.linspace(0, 1, 100)

for i in range(5):
    plt.plot(x, y[i,:])
plt.show()

# %%
y.shape
# Out:
# (150, 100)

# %%
d = np.load("antiderivative_aligned_train.npz", allow_pickle=True)
X_train, y_train = (d["X"][0], d["X"][1]), d["y"]

# %%
u = X_train[0]

# %%
plt.plot(x, u[1])
plt.plot(x, y_train[1])
plt.show()

# %%
y_train.shape
# Out:
# (150, 100)
